# %% [markdown]
# <a href="https://colab.research.google.com/github/techmanu22/InternshalaScraping/blob/main/InternshalaScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install beautifulsoup4

# %%
# !pip install bs4
# !pip install requests

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
  location=str(input("Enter your location"))
  page=requests.get("https://internshala.com/internships/internship-in-"+location)
  time.sleep(2)
  soup=BeautifulSoup(page.text,'html.parser')
  links=soup.find_all('div',attrs={'class':'heading_4_5 profile'})
  company_name=soup.find_all('div',attrs={'class':'heading_6 company_name'})
  duration=soup.find_all('div',attrs={'class':'item_body'})
  stipend=soup.find_all('span',attrs={'class':'stipend'})
  total_pages=soup.find_all('span',attrs={'id':'total_pages'})
  print("Total pages are",total_pages)
  pg_number=str(input("Enter the page number"))
  page=requests.get("https://internshala.com/internships/internship-in-"+location+"//page-"+pg_number)
  time.sleep(2)
  soup=BeautifulSoup(page.text,'html.parser')
  links=soup.find_all('div',attrs={'class':'heading_4_5 profile'})
  company_name=soup.find_all('div',attrs={'class':'heading_6 company_name'})
  duration=soup.find_all('div',attrs={'class':'item_body'})
  stipend=soup.find_all('span',attrs={'class':'stipend'})
  total_pages=soup.find_all('span',attrs={'id':'total_pages'})


except Exception as e:
  error_type,error_obj,error_info = sys.exc_info()
  print('ERROR FOR LINK;',url)
  print(error_type,'Line:',error_info.tb_lineno)
# Out:
# Enter your locationPune
# Total pages are [<span id="total_pages">15</span>]
# Enter the page number3

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# ...

# %%
links
# Out:
# [<div class="heading_4_5 profile">
#  <a href="/internship/detail/business-development-sales-internship-in-multiple-locations-at-byjus-the-learning-app1635416267">Business Development (Sales)</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/internship/detail/social-media-marketing-internship-in-mumbai-at-fashion-tv1635248301">Social Media Marketing</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/internship/detail/program-management-internship-in-multiple-locations-at-biocon-limited1635323888">Program Management</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/internship/detail/client-servicing-internship-in-mumbai-at-percept1635161439">Client Servicing</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/internship/detail/operations-csr-internship-in-mumbai-at-colgate-palmolive-india-limited1635308279">Operations (CSR)</a> </div>,
#  <div class="heading_4_5 profile">
# ...

# %%
company_name
# Out:
# [<div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/internships/internship-at-BYJU%27S%20The%20Learning%20App">
#                          BYJU'S The Learning App                    </a>
#  </div>, <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/internships/internship-at-Fashion%20TV">
#                          Fashion TV                    </a>
#  </div>, <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/internships/internship-at-Biocon%20Limited">
#                          Biocon Limited                    </a>
#  </div>, <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/internships/internship-at-Percept">
#                          Percept                    </a>
#  </div>, <div class="heading_6 company_name">
#  <a class="link_display_like_text" href="/internships/internship-at-Colgate%20Palmolive%20%28India%29%20Limited">
# ...

# %%
stipend
# Out:
# [<span class="stipend"><i class="ic-16-currency-inr"></i> 18000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 2500 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 10000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 5000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 15000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 10000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 5000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 20000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 5000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 8000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 10000 /month</span>,
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 2500 /month</span>,
# ...

# %%
duration
# Out:
# [<div class="item_body" id="start-date-first">
#  <span class="start_immediately_mobile">Starts immediately</span><span class="start_immediately_desktop">Immediately</span> </div>,
#  <div class="item_body">
#                              6 Months                        </div>,
#  <div class="item_body">
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 18000 /month</span> </div>,
#  <div class="item_body">11 Nov' 21</div>,
#  <div class="item_body" id="start-date-first">
#  <span class="start_immediately_mobile">Starts immediately</span><span class="start_immediately_desktop">Immediately</span> </div>,
#  <div class="item_body">
#                              3 Months                        </div>,
#  <div class="item_body">
#  <span class="stipend"><i class="ic-16-currency-inr"></i> 2500 /month</span> </div>,
#  <div class="item_body">10 Nov' 21</div>,
#  <div class="item_body" id="start-date-first">
# ...

# %%
for i, j, k, l in zip(links,company_name,duration,stipend):
  print("The internship Profile: ",i.text)
  print("Company Name: ",j.text.strip())
  print("Duration: ",k.text.strip())
  print("Stipend",l.text,"\n")
  print("***********")
# Out:
# The internship Profile:
# Content Writing
# Company Name:  Neologic Engineer Pvt. Ltd.
# Duration:  Starts immediatelyImmediately
# Stipend  7000 /month
#
# ***********
# The internship Profile:
# Digital Marketing
# Company Name:  Reports Insights Consulting Private Limited
# Duration:  6 Months
# Stipend  5000-8000 /month
#
# ***********
# The internship Profile:
# Architecture & Interior Design
# Company Name:  Mahaveer Patil And Associates
# Duration:  7000 /month
# Stipend  4000-9000 /month
#
# ***********
# The internship Profile:
# ASP.NET Development
# Company Name:  OTOQual Technologies
# Duration:  10 Nov' 21
# Stipend  7000-9000 /month
#
# ***********
# The internship Profile:
# Business Analysis
# Company Name:  Vishwasya Technologiess Private Limited
# Duration:  Starts immediatelyImmediately
# Stipend  5000 /month
#
# ***********
# The internship Profile:
# Graphic Design
# Company Name:  BM Confianca
# Duration:  6 Months
# Stipend  4000-9000 /month
#
# ***********
# ...
